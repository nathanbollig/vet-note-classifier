# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# example data

model_types = ["Base", "Random Forest", "Logistic Regression"]
measures = ["F1", "Recall", "Precision"]

key_key = ['base','test_rf','test_lr']

test_results = dict(
    base_f1 = 14.001,
    base_f1_l = 9.940,
base_f1_u = 17.905,

base_recall = 100.000,
base_recall_l = 100.000,
base_recall_u = 100.000,

base_precision = 7.515,
base_precision_l = 5.230,
base_precision_u = 9.833,

base_accuracy = 7.580,
base_accuracy_l = 5.230,
base_accuracy_u = 9.833,
    
test_rf_f1 = 19.431,
test_rf_f1_l = 14.054,
test_rf_f1_u = 25.000,

test_rf_recall = 100.000,
test_rf_recall_l = 100.000,
test_rf_recall_u = 100.000,

test_rf_precision = 10.677,
test_rf_precision_l = 7.602,
test_rf_precision_u = 14.077,

test_rf_accuracy = 37.294,
test_rf_accuracy_l = 33.264,
test_rf_accuracy_u = 41.632,

test_rf_avg_prec = 22.274,
test_rf_avg_prec_l = 13.326,
test_rf_avg_prec_u = 32.443,

test_lr_f1 = 19.885,
test_lr_f1_l = 14.679,
test_lr_f1_u = 25.557,

test_lr_recall = 100.000,
test_lr_recall_l = 100.000,
test_lr_recall_u = 100.000,

test_lr_precision = 11.121,
test_lr_precision_l = 7.941,
test_lr_precision_u = 14.578,

test_lr_accuracy = 39.825,
test_lr_accuracy_l = 35.774,
test_lr_accuracy_u = 44.142,

test_lr_avg_prec = 31.329,
test_lr_avg_prec_l = 18.590,
test_lr_avg_prec_u = 46.017
)
    
#####F1    
f1_keys = [f"{k}_f1" for k in key_key]
f1_keys_l = [f"{k}_f1_l" for k in key_key]
f1_keys_u = [f"{k}_f1_u" for k in key_key]

x_pos_f1 = np.arange(start=0, stop = 15 ,step =5)

# lower & upper limits of the error
y_pos_f1 = np.array([test_results[k] for k in f1_keys])
lo_f1 = np.array([test_results[k] for k in f1_keys_l])
hi_f1 = np.array([test_results[k] for k in f1_keys_u])

fig, ax = plt.subplots(figsize=(6, 4))
ax.errorbar(x_pos_f1, y_pos_f1, yerr=[y_pos_f1-lo_f1, hi_f1-y_pos_f1], 
            markeredgewidth =2, elinewidth = 1, capsize =4,
           marker='o', markersize=3,
           linestyle='', color = 'dodgerblue', label = "F1")


#####Recall
recall_keys = [f"{k}_recall" for k in key_key]
recall_keys_l = [f"{k}_recall_l" for k in key_key]
recall_keys_u = [f"{k}_recall_u" for k in key_key]

x_pos_recall = np.arange(start=1, stop = 16 ,step =5)

# lower & upper limits of the error
y_pos_recall = np.array([test_results[k] for k in recall_keys])
lo_recall = np.array([test_results[k] for k in recall_keys_l])
hi_recall = np.array([test_results[k] for k in recall_keys_u])

ax.errorbar(x_pos_recall, y_pos_recall, yerr=[y_pos_recall - lo_recall, hi_recall - y_pos_recall], 
            markeredgewidth =2, elinewidth = 1, capsize =4,
           marker='o', markersize=3,
           linestyle='', color = 'green', label = "Recall")

#####precision
precision_keys = [f"{k}_precision" for k in key_key]
precision_keys_l = [f"{k}_precision_l" for k in key_key]
precision_keys_u = [f"{k}_precision_u" for k in key_key]

x_pos_precision = np.arange(start=2, stop = 17 ,step =5)

# lower & upper limits of the error
y_pos_precision = np.array([test_results[k] for k in precision_keys])
lo_precision = np.array([test_results[k] for k in precision_keys_l])
hi_precision = np.array([test_results[k] for k in precision_keys_u])

ax.errorbar(x_pos_precision, y_pos_precision, 
            yerr=[y_pos_precision - lo_precision, hi_precision - y_pos_precision], 
            markeredgewidth =2, elinewidth = 1, capsize =4,
           marker='o', markersize=3,
           linestyle='', color = 'red', label = "Precision")


ax.hlines(y_pos_precision[0], x_pos_precision[0], x_pos_precision[2],
         linestyles='dotted', color = 'firebrick')

ax.hlines(hi_precision[0], x_pos_precision[0], x_pos_precision[2],
         linestyles='dotted', color = 'grey')


plt.xticks([1,6,11], model_types)
plt.xlabel("Model", fontsize=14)
plt.ylabel("Value", fontsize=14)
plt.legend(fontsize = 12)
#ax.set_xticklabels(X_ticks)

# change the fontsize of minor ticks label 
ax.tick_params(axis='both', which='major', labelsize=12)

# # tidy up the figure
ax.set_xlim((-1,13))
ax.set_title('Experiment 1 Results', fontsize=18)
plt.show()

# %%
# example data

model_types = ["Base", "Random Forest", "Logistic Regression"]
measures = ["F1", "Recall", "Precision"]

key_key = ['base','test_rf','test_lr']

test_results = dict(
    base_f1 = 12.976,
    base_f1_l = 9.954,
base_f1_u = 15.919,

base_recall = 100.000,
base_recall_l = 100.000,
base_recall_u = 100.000,

base_precision = 6.972,
base_precision_l = 5.238,
base_precision_u = 8.770,
    
test_rf_f1 = 29.958,
test_rf_f1_l = 18.495,
test_rf_f1_u = 40.911,

test_rf_recall = 29.835,
test_rf_recall_l = 18.177,
test_rf_recall_u = 41.667,

test_rf_precision = 30.743,
test_rf_precision_l = 19.144,
test_rf_precision_u = 43.335,

test_rf_avg_prec = 26.962,
test_rf_avg_prec_l = 18.094,
test_rf_avg_prec_u = 37.741,

test_lr_f1 = 9.342,
test_lr_f1_l = 0.00,
test_lr_f1_u = 19.725,

test_lr_recall = 5.285,
test_lr_recall_l = 0.00,
test_lr_recall_u = 11.667,

test_lr_precision = 50.063,
test_lr_precision_l = 0.00,
test_lr_precision_u = 100.00,

test_lr_avg_prec = 45.699,
test_lr_avg_prec_l = 32.632,
test_lr_avg_prec_u = 58.632
)
    
#####F1    
f1_keys = [f"{k}_f1" for k in key_key]
f1_keys_l = [f"{k}_f1_l" for k in key_key]
f1_keys_u = [f"{k}_f1_u" for k in key_key]

x_pos_f1 = np.arange(start=0, stop = 15 ,step =5)

# lower & upper limits of the error
y_pos_f1 = np.array([test_results[k] for k in f1_keys])
lo_f1 = np.array([test_results[k] for k in f1_keys_l])
hi_f1 = np.array([test_results[k] for k in f1_keys_u])

fig, ax = plt.subplots(figsize=(6, 4))
ax.errorbar(x_pos_f1, y_pos_f1, yerr=[y_pos_f1-lo_f1, hi_f1-y_pos_f1], 
            markeredgewidth =2, elinewidth = 1, capsize =4,
           marker='o', markersize=3,
           linestyle='', color = 'dodgerblue', label = "F1")


#####Recall
recall_keys = [f"{k}_recall" for k in key_key]
recall_keys_l = [f"{k}_recall_l" for k in key_key]
recall_keys_u = [f"{k}_recall_u" for k in key_key]

x_pos_recall = np.arange(start=1, stop = 16 ,step =5)

# lower & upper limits of the error
y_pos_recall = np.array([test_results[k] for k in recall_keys])
lo_recall = np.array([test_results[k] for k in recall_keys_l])
hi_recall = np.array([test_results[k] for k in recall_keys_u])

ax.errorbar(x_pos_recall, y_pos_recall, yerr=[y_pos_recall - lo_recall, hi_recall - y_pos_recall], 
            markeredgewidth =2, elinewidth = 1, capsize =4,
           marker='o', markersize=3,
           linestyle='', color = 'green', label = "Recall")

#####precision
precision_keys = [f"{k}_precision" for k in key_key]
precision_keys_l = [f"{k}_precision_l" for k in key_key]
precision_keys_u = [f"{k}_precision_u" for k in key_key]

x_pos_precision = np.arange(start=2, stop = 17 ,step =5)

# lower & upper limits of the error
y_pos_precision = np.array([test_results[k] for k in precision_keys])
lo_precision = np.array([test_results[k] for k in precision_keys_l])
hi_precision = np.array([test_results[k] for k in precision_keys_u])

ax.errorbar(x_pos_precision, y_pos_precision, 
            yerr=[y_pos_precision - lo_precision, hi_precision - y_pos_precision], 
            markeredgewidth =2, elinewidth = 1, capsize =4,
           marker='o', markersize=3,
           linestyle='', color = 'red', label = "Precision")

plt.xticks([1,6,11], model_types)
plt.xlabel("Model", fontsize=14)
plt.ylabel("Value", fontsize=14)
plt.legend(fontsize = 12)
#ax.set_xticklabels(X_ticks)

# change the fontsize of minor ticks label 
ax.tick_params(axis='both', which='major', labelsize=12)

# # tidy up the figure
ax.set_xlim((-1,13))
ax.set_title('Experiment 2 Results', fontsize=18)
plt.show()

# %%
experiments = ["Random Forest", "Logistic Regression"]

x_pos = np.arange(len(experiments))
exp1_rf_ap = 22.274
exp1_rf_ap_l = 13.326
exp1_rf_ap_u = 32.443

exp2_rf_ap = 40.430
exp2_rf_ap_l = 17.564
exp2_rf_ap_u = 65.562

x_pos_rf = np.array([0,5])
y_pos_rf = np.array([exp1_rf_ap, exp2_rf_ap])
error_l = np.array([exp1_rf_ap_l, exp2_rf_ap_l])
error_u = np.array([exp1_rf_ap_u, exp2_rf_ap_u])

fig, ax = plt.subplots()
ax.bar(x_pos_rf, y_pos_rf, yerr=[y_pos_rf - exp2_rf_ap_l, exp2_rf_ap_u - y_pos_rf], 
       align='center', alpha=0.5, ecolor='black', capsize=10, color = "blue")


x_pos = np.arange(len(experiments))
exp1_lr_ap = 31.329
exp1_lr_ap_l = 18.59
exp1_lr_ap_u = 46.017

exp2_lr_ap = 45.699
exp2_lr_ap_l = 32.632
exp2_lr_ap_u = 58.632

x_pos_lr = np.array([1,6])
y_pos_lr = np.array([exp1_lr_ap, exp2_lr_ap])
error_l = np.array([exp1_lr_ap_l, exp2_lr_ap_l])
error_u = np.array([exp1_lr_ap_u, exp2_lr_ap_u])

ax.bar(x_pos_lr, y_pos_lr, yerr=[y_pos_lr - error_l, error_u - y_pos_lr], 
       align='center', alpha=0.5, ecolor='black', capsize=10, color = "green")


plt.xticks([0, 1, 5, 6],["RF", "LR", "RF", "LR"])

plt.xlabel("Experiment 1                                 Experiment 2", fontsize=14)
plt.ylabel("Value", fontsize=14)
#plt.legend(fontsize = 12)


# change the fontsize of minor ticks label 
ax.tick_params(axis='both', which='major', labelsize=12)

# # tidy up the figure
ax.set_title('Average Precision', fontsize=18)

# Save the figure and show
plt.tight_layout()
plt.savefig('bar_plot_with_error_bars.png')
plt.show()
